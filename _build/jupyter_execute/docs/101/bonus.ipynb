# %% [markdown]
# # Bonus Material
#
# ## <i class="fa-solid fa-person-digging"></i>
#
# This part builds on the foundations from [Part 1](../101/part1) and [Part 2](../101/part2).
#
# For now, this is only bonus material and a work in progress, so errors may occur.
#
# It may eventually become its own separate course(s) in the future.

# %% [markdown]
# ---
# ## Content

# %% [markdown]
# ```{tableofcontents}
# ```
