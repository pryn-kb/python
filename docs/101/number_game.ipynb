# %%
import random
# Generate a random secret number between 1 and 20
secret_number = random.randint(1, 20)
#print(secret_number)

user_input = None
attempts = 0

print("Welcome to the Number Guessing Game!")

while user_input != secret_number:

    user_input = input("Guess the secret number (1-20): ")
    user_input = int(user_input)
    attempts += 1

    if user_input < secret_number:
        print("Too low. Try again.")
    elif user_input > secret_number:
        print("Too high. Try again.")
    else:
        print("Congratulations! You guessed the correct number in", attempts, "attempts.")
# Out:
# Welcome to the Number Guessing Game!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 13
#       9 print("Welcome to the Number Guessing Game!")
#      11 while user_input != secret_number:
# ---> 13     user_input = input("Guess the secret number (1-20): ")
#      14     user_input = int(user_input)
#      15     attempts += 1
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
